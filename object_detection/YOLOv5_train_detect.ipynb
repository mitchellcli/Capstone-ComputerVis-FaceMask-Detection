# %%
# yolo setup
# !git clone https://github.com/ultralytics/yolov5 # clone repo
# !pip install -U -r yolov5/requirements.txt # install dependencies
# !pip install facenet-pytorch

# %%
# import data
import zipfile
with zipfile.ZipFile('4_12_img_w_original.zip', 'r') as zip_ref:
    zip_ref.extractall('content2/')

# %%
# train model
# !python yolov5/train.py --img 416 --batch 16 --epochs 30 --data /home/ubuntu/content2/data.yaml --cfg yolov5/models/yolov5x.yaml --weights runs/train/exp/weights/best.pt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# github: skipping check (not a git repository)
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# ...

# %%
# run detection
# !python yolov5/detect.py --weights runs/train/exp15/weights/best.pt --source MixedMask.mp4 --iou-thres 0.3 --conf-thres 0.25
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='MixedMask.mp4', update=False, view_img=False, weights=['runs/train/exp15/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 476 layers, 87232339 parameters, 0 gradients, 217.2 GFLOPS
# video 1/1 (1/376) /home/ubuntu/MixedMask.mp4: 384x640 2 No Masks, 2 Nonmedical Fulls, 3 Medical Fulls, Done. (1.260s)
# video 1/1 (2/376) /home/ubuntu/MixedMask.mp4: 384x640 2 No Masks, 2 Nonmedical Fulls, 3 Medical Fulls, Done. (1.244s)
# ...

# %%
# run detection on another video
# !python yolov5/detect.py --weights runs/train/exp15/weights/best.pt --source metro_people.mp4 --iou-thres 0.3 --conf-thres 0.3
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, img_size=640, iou_thres=0.3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='metro_people.mp4', update=False, view_img=False, weights=['runs/train/exp5/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 476 layers, 87232339 parameters, 0 gradients, 217.2 GFLOPS
# video 1/1 (1/3321) /home/ubuntu/metro_people.mp4: 384x640 1 1, 9 3s, Done. (1.270s)
# video 1/1 (2/3321) /home/ubuntu/metro_people.mp4: 384x640 1 1, 8 3s, Done. (1.255s)
# video 1/1 (3/3321) /home/ubuntu/metro_people.mp4: 384x640 1 1, 6 3s, Done. (1.256s)
# ...

# %%
# run detection on validation images for analysis
# !python yolov5/detect.py --weights runs/train/exp15/weights/best.pt --source /home/ubuntu/content2/valid/images/ --img 416 --iou-thres 0.3 --conf-thres 0.3 --save-txt
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, img_size=416, iou_thres=0.3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=True, source='/home/ubuntu/content2/valid/images/', update=False, view_img=False, weights=['runs/train/exp15/weights/best.pt'])
# YOLOv5 🚀 v4.0-184-g9ccfa85 torch 1.8.1+cu102 CPU
#
# Fusing layers...
# Model Summary: 476 layers, 87232339 parameters, 0 gradients, 217.2 GFLOPS
# image 1/415 /home/ubuntu/content2/valid/images/01EXZFTN956DTX4B7B1S7V62XV_jpeg_jpg.rf.5761c75e03473020b498727a69993f95.jpg: 416x416 1 Medical Full, Done. (0.920s)
# ...

# %%
# zip image prediction outputs for download
# !zip -r content2/valid_preds_yolo_4_14.zip runs/detect/exp26
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
#   adding: runs/detect/exp26/ (stored 0%)
#   adding: runs/detect/exp26/maksssksksss347_png_jpg.rf.0faefe4050a0d48069a9d8449aeae5ef.jpg (deflated 3%)
#   adding: runs/detect/exp26/01F07FWTCJ5Y8T023GY8ENRAWG_jpeg_jpg.rf.d1d6970a84633edfb395b9e4af2f2424.jpg (deflated 5%)
#   adding: runs/detect/exp26/01EY040P5Q9VWTE6R6Y6FJ6Z4X_jpeg_jpg.rf.5cf3a3db7bdc922462817bf6893f2db2.jpg (deflated 4%)
#   adding: runs/detect/exp26/skull-skeleton-bandana-mask-black-4_jpg.rf.ef49a1e2041155951664fe23f6383261.jpg (deflated 7%)
#   adding: runs/detect/exp26/0_0_0--118-_jpg.rf.c675feabc42849d3b478fdbe7b334984.jpg (deflated 5%)
# ...
